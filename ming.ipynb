# %% [markdown]
# # 영어

# %%
import numpy as np
import pandas as pd

text_data = pd.read_csv("news_summary.csv", header=None, encoding = "ISO-8859-1")

text_all = text_data[5].values

# %%
# -*- coding: utf-8 -*-

from __future__ import absolute_import
from __future__ import division, print_function, unicode_literals

from sumy.parsers.html import HtmlParser
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.edmundson import EdmundsonSummarizer
from sumy.summarizers.text_rank import TextRankSummarizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.summarizers.sum_basic import SumBasicSummarizer
from sumy.summarizers.kl import KLSummarizer
from sumy.nlp.stemmers import Stemmer
from sumy.utils import get_stop_words, ItemsCount

SENTENCES_COUNT = ItemsCount(2)

def build_summarizer(summarizer_class, stop_words, stemmer, parser):
    summarizer = summarizer_class(stemmer)
    if summarizer_class is EdmundsonSummarizer:
        summarizer.null_words = stop_words
        summarizer.bonus_words = parser.significant_words
        summarizer.stigma_words = parser.stigma_words
    else:
        summarizer.stop_words = stop_words
    return summarizer

# %%
AVAILABLE_METHODS = {
    "luhn": LuhnSummarizer,
}

def start_text(text, LANGUAGE, ALGORITHM):
    if __name__ == "__main__":
        parser = PlaintextParser.from_string(text, Tokenizer(LANGUAGE))
        stemmer = Stemmer(LANGUAGE)
        summarizer = build_summarizer(ALGORITHM, get_stop_words(LANGUAGE), stemmer, parser)
        hi = ''
        for sentence in summarizer(parser.document, SENTENCES_COUNT):
            hi+=str(sentence)
        return hi

# %%
result = np.array([])

for i, j in AVAILABLE_METHODS.items():
    for k in range(1, len(text_all)):
        hi = []
        summarize = start_text(text_all[k], 'english', j)
        hi.append(summarize)
        result = np.append(result, hi, axis = 0)
        df = pd.DataFrame(result)
        name = "extract_" + i
        df.to_csv(name + ".csv")
    print(i + "done")
# Out:
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# /home/dvlab/nltk_data/tokenizers/punkt/english.pickle
# ...

# %% [markdown]
# # 한국어

# %%
result = np.array([])

text_data = pd.read_csv("news_kor.csv", header=None, encoding = "utf-8")

text_all = text_data[1].values

for i, j in AVAILABLE_METHODS.items():
    for k in range(1, len(text_all)):
        hi = []
        summarize = start_text(text_all[k], 'korean', j)
        hi.append(summarize)
        result = np.append(result, hi, axis = 0)
        df = pd.DataFrame(result)
        name = "kor_extract_" + i
        df.to_csv(name + ".csv")
    print(i + "done")
# Out:
# luhndone
